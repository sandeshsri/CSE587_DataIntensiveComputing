# %%
import Predictive_Analytics
# Out:
# Dataset dimension:  40956 x 49
# Training samples:  32764
# Validation samples:  4096
# Testing samples:  4096
# -------------------- Part 2 --------------------
# SVM accuracy : 0.895508
# Logisitic Regression accuracy : 0.879150
# Decision Tree accuracy : 0.979980
# KNN accuracy : 0.987305
# Voting Classifier accuracy : 0.933105
# -------------------- Part 1 --------------------
# KNN accuracy : 0.986572
# Random forest
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-d3af7b4f88ea> in <module>
# ----> 1 import Predictive_Analytics
#
# ~\Projects\DIC587\Assignment1\Predictive_Analytics.py in <module>
#     462
#     463 print("Random forest")
# --> 464 RandomForest(train_X,train_y,test_X)
#     465
#     466 K = len(data_y.unique()) #Number of clusters
#
# ~\Projects\DIC587\Assignment1\Predictive_Analytics.py in RandomForest(X_train, Y_train, X_test)
# ...
